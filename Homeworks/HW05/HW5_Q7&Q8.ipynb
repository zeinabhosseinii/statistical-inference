# %%
#ًQuestion 7:

# Given data for absence counts
absence_counts <- c(18, 16, 10, 10, 16)
chi_square_stat <- 0

# Expected values
expected_values <- c(14, 14, 14, 14, 14)

chi_square_test <- chisq.test(absence_counts)
chi_square_test
# Out:
# 	Chi-squared test for given probabilities
#
# data:  absence_counts
# X-squared = 4, df = 4, p-value = 0.406

# %%
#ًQuestion 8:

library(MASS)
data(survey)

contingency_table <- table(survey$Smoke, survey$Exer)

chi_square_result <- chisq.test(contingency_table)
chi_square_result
# Out:
# Warning message in chisq.test(contingency_table):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  contingency_table
# X-squared = 5.4885, df = 6, p-value = 0.4828
